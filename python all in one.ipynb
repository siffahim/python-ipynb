# %%
print("Restart")
# Out:
# Restart

# %%
print("Allah give me on more chance to get my dream", end=" ")
print("Ya allah")
# Out:
# Allah give me on more chance to get my dream Ya allah

# %%
#this is one line comment
print("One Line")

w = """This is multiple line comment"""
print("Multiple Line: "+ w)
# Out:
# One Line
# Multiple Line: This is multiple line comment

# %%
name = "Fahim"
age = 25
isSeak = True
cgpa = 3.5

#Checing Types
print(type(name), type(age), type(isSeak), type(cgpa))
# Out:
# <class 'str'> <class 'int'> <class 'bool'> <class 'float'>

# %%
#type casting
x = float(4);

print(type(x))
# Out:
# <class 'float'>

# %%
#Assign variable
#Multiple value to many variable
x,y, z = "Orange", "Banana", "Apple";


print(x)
print(y)
print(z)

#One to value to multiple variable
a = b = c = "FIFA"

print(a)
print(b)
print(c)
# Out:
# Orange
# Banana
# Apple
# FIFA
# FIFA
# FIFA

# %%
#String

text = "FIFA '2026' IN USA"

multiple_line = """Argentina player Leonal Messi
Did hattrick
at miami match"""



print(text)
print(text[0])
#Length
print(len(text))
#in
print("2026" in text)
#not in
print("2026" not in text)
print(multiple_line)
# Out:
# FIFA '2026' IN USA
# F
# 18
# True
# False
# Argentina player Leonal Messi
# Did hattrick
# at miami match

# %%
#String Slicing
txt = "England vs Crotia";

print(txt[2:7])
#From the start
print(txt[:7])
#To end
print(txt[0:])

print(txt[-6:-1])

#Upper
print(txt.upper())

#Lower
print(txt.lower())

#Stripe for remove whitespace
print(txt.strip())

#for replacing the value
print(txt.replace("Crotia", "Brazil"))

#For separating the text
print(txt.split(" "))

list_txt = txt.split(" ");

info = ("_").join(list_txt);

print(info)
# Out:
# gland
# England
# England vs Crotia
# Croti
# ENGLAND VS CROTIA
# england vs crotia
# England vs Crotia
# England vs Brazil
# ['England', 'vs', 'Crotia']
# England_vs_Crotia

# %%
#Formating string

print(f"My name is {name}, and age is {age:.2f}")

print("This food call {},\n and \t  this vaggies call {}".format("Mango","Carrot"))


#ecaping char
print("I Hey, it's \"Fahim\"")
print("Divided to 2\\4")
# Out:
# My name is Fahim, and age is 25.00
# This food call Mango,
#  and 	  this vaggies call Carrot
# I Hey, it's "Fahim"
# Divided to 2\4

# %%
#String Method

t = "bangladesh is a corrupted cournty";

print("Checkiing ends char: ",t.endswith("z"))
print("Checing start char: ", t.startswith("b"))
print("Convert only first char: ",t.capitalize())
print("Covnert lower case to all char: ",t.casefold())
print("Find the position of char: ", t.index("a"))
print("Finding the position of the value: ", t.find("is"))
print("Convert each of first char to Upper: ",t.title())
print("become upper case to lower and vice versa: ",t.swapcase())
print(t.encode())
print(t.count("bangladesh"))
print(t.center(20))
# Out:
# Checkiing ends char:  False
# Checing start char:  True
# Convert only first char:  Bangladesh is a corrupted cournty
# Covnert lower case to all char:  bangladesh is a corrupted cournty
# Find the position of char:  1
# Finding the position of the value:  11
# Convert each of first char to Upper:  Bangladesh Is A Corrupted Cournty
# become upper case to lower and vice versa:  BANGLADESH IS A CORRUPTED COURNTY
# b'bangladesh is a corrupted cournty'
# 1
# bangladesh is a corrupted cournty

# %%
#Condition
age = 13
if age > 18:
  print("You can vote!!")
else:
  print("You can't vote!!")


amount = 40;
coupon = True;

if amount > 50:
  print("You can purchase by amount")
elif coupon:
  print("Yes, You can purchase through coupon")
else:
  print("Insufficiant balance")


#Short if else
a = 50;
b = 30;
print("A") if a > b else print("B")

username = ""
display_name = username if username else "Guest";

print(display_name)
# Out:
# You can't vote!!
# Yes, You can purchase through coupon
# A
# Guest

# %%
#List
l = ["Apple","Orange","Jackfruits","Mango","Licu","Banana"]

l[1] = "Blue Berry"
#Value append in the end of list
l.append("Water Malon")
#Value insert in any position
l.insert(1, "Tomato")

#delete value
l.pop()

l.remove("Blue Berry")
print(l)
print(len(l))
print(type(l))

print(l[1])
print(l[:4])
print("Man" in l);
# Out:
# ['Apple', 'Tomato', 'Jackfruits', 'Mango', 'Licu', 'Banana']
# 6
# <class 'list'>
# Tomato
# ['Apple', 'Tomato', 'Jackfruits', 'Mango']
# False

# %%
#sort
numbers = [10,60,32,54,100,20];

#numbers.sort(reverse=True)
numbers.sort();

numbers.reverse()

print(numbers)
# Out:
# [100, 60, 54, 32, 20, 10]

# %%
#Stack
stack = [] #LIFO;

#insert value to stack
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)

#Remove
stack.pop()
stack.pop()


print(stack.pop())
# Out:
# 3

# %%
queqe = []

#insert value to queqe
queqe.append(1)
queqe.append(2)
queqe.append(3)
queqe.append(4)
queqe.append(5)


#remove the value from the first
queqe.pop(0)
queqe.pop(0)

print(queqe[0])
# Out:
# 3

# %%
#list comprehention

#number
random_list = [x for x in range(1, 10) if x%2 == 0]

print(random_list)

#string
fruits = ["Apple","Orange","Mango","Watermelon"];
newlist = [fruit for fruit in fruits if fruit not in "Apple"]


print(newlist)
# Out:
# [2, 4, 6, 8]
# ['Orange', 'Mango', 'Watermelon']

# %%
#Tuples
tup = (10,20,30,50);

print(type(tup), tup)

new_tup = tup[1:3];

print(new_tup)

#Tuples types
tup_str = ("A","B","C")
tup_num = (40,4,5,5)
mix_tup = (True, 3, "App")

for v in tup_str:
  print("LOOP: ", v)


#loop through by range
for i in range(len(tup_num)):
  print("Access through index: ", tup_num[i])

print(mix_tup)

#tuples join
tup_join = tup_num + tup_str;

print(tup_join)

#Tuples method
print(tup_num.count(5))
print(tup_num.index(4))

#upack tuples
(x, y, *z) = tup_join;

print(x,y,z)
# Out:
# <class 'tuple'> (10, 20, 30, 50)
# (20, 30)
# LOOP:  A
# LOOP:  B
# LOOP:  C
# Access through index:  40
# Access through index:  4
# Access through index:  5
# Access through index:  5
# (True, 3, 'App')
# (40, 4, 5, 5, 'A', 'B', 'C')
# 2
# 1
# 40 4 [5, 5, 'A', 'B', 'C']

# %%
#tumple immutibility

cars = ("Audi","BMW", "Toyota","Corola")

#cars[2] = "BYD"

print(cars)
# Out:
# ('Audi', 'BMW', 'Toyota', 'Corola')

# %%
 #SET

a = {1,2,3}
b = {2,3,4}

print(type(a))
# Out:
# <class 'set'>

# %%
#Empty set
list = []

print(type(list))

tup = ()

print(type(tup))

s = {} #it's getting error for empty set
s = set()
print(type(s))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
s = {1,2,3,4,5,5,5}

for item in s:
  print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#SET Method

a = {2,3}
b = {2,3,4}

print(a.union(b)) #union will print one time without duply value
print(a.intersection(b)) #it print's common values

print(a.isdisjoint(b))
print(a.issubset(b))
# Out:
# {2, 3, 4}
# {2, 3}
# False
# True

# %%
x = {10,20,30,40,50}

#add item
# x.add(100)
# x.add(0)
# x.add(60)

# #remove item
# x.pop()
# x.pop()

#remove on specific itme
x.remove(100) #it's generate error if the item isn't exist discard() is not showing error if not exist the value
x.discard(100)

print(x)
# Out:
# {50, 20, 40, 10, 30}

# %%
#Dictionary

#Duplicate key isn't allow
student = {
    "name": "Cucure",
    "age": 25,
    "weight": 70,
    "id": 20
}


print(type(student), student)


print(len(student))

#access
print(student["name"])

print(student.get("age"))

print(student.keys())

print(student.values())

student["name"] = "Fahim";

print(student)

print(student.items())

#add & change
student["BMI"] = "220UML"
student.update({"CBC": "Good"})

print(student.items())
# Out:
# <class 'dict'> {'name': 'Cucure', 'age': 25, 'weight': 70, 'id': 20}
# 4
# Cucure
# 25
# dict_keys(['name', 'age', 'weight', 'id'])
# dict_values(['Cucure', 25, 70, 20])
# {'name': 'Fahim', 'age': 25, 'weight': 70, 'id': 20}
# dict_items([('name', 'Fahim'), ('age', 25), ('weight', 70), ('id', 20)])
# dict_items([('name', 'Fahim'), ('age', 25), ('weight', 70), ('id', 20), ('BMI', '220UML'), ('CBC', 'Good')])

# %%
#dictionary delete

car = {
    "brand": "Roll Royal",
    "model": "R3OW",
    "color": ["White","Golden", "Black"],
    "price": 100000
}

#delete
del car["model"]
car.pop("color")

#delete last itme from the dict
car.popitem()

#clear and delelte
#del car
car.clear()
print(car)
# Out:
# {}

# %%
#Loop into dictionary

fruits = {
    "name": "Mango",
    "isGood": True,
    "price": 10,
    "foodFrom": "Aus"
}


#print all the keys
# for x in fruits:
#   print(x)

#print the value by keys
for x in fruits:
  print(fruits[x])
# Out:
# Mango
# True
# 10
# Aus

# %%
fruits = {
    "name": "Mango",
    "isGood": True,
    "price": 10,
    "foodFrom": "Aus"
}

for value in fruits.values():
  print(value)

print("key--------------------")

for key in fruits.keys():
  print(key)


print("Items_------------------")

for x,y in fruits.items():
  print(x)
# Out:
# Mango
# True
# 10
# Aus
# key--------------------
# name
# isGood
# price
# foodFrom
# Items_------------------
# name
# isGood
# price
# foodFrom

# %%
#Dic copy

st = {
    "a": "a",
    "b": "b"
  }


final_st = st.copy()
final_st2 = dict(st)

print(final_st2)
# Out:
# {'a': 'a', 'b': 'b'}

# %%
#comprehensive dict

square = {x: x**2 for x in range(1, 11)}


print(square)


cor_location = [(10.23, 20), (23, 25.32), (11, 11.5)]
location = ["Dhaka","Rajshahi","Barisal"];


exact_location = {loc: cor for cor, loc in zip(location, cor_location)}

print(exact_location)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {(10.23, 20): 'Dhaka', (23, 25.32): 'Rajshahi', (11, 11.5): 'Barisal'}
