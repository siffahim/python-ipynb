# %%
name = input("What's your name: ");

print(name);
# Out:
# Pawwwwwwwwww

# %%
age = int(input("What's your age: "));

print(age, type(age));
# Out:
# 25 <class 'int'>

# %%
price = int(input("How much?: "));

price = price + 5;

print(price);
# Out:
# 30
