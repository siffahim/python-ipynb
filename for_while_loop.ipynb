# %%
for i in range(10):
    print(i, "Hello World!");
# Out:
# 0 Hello World!
# 1 Hello World!
# 2 Hello World!
# 3 Hello World!
# 4 Hello World!
# 5 Hello World!
# 6 Hello World!
# 7 Hello World!
# 8 Hello World!
# 9 Hello World!

# %%
for i in range(1, 10, 2):
    print(i, "Hello!!")
# Out:
# 1 Hello!!
# 3 Hello!!
# 5 Hello!!
# 7 Hello!!
# 9 Hello!!

# %%
i = 1;
while i <= 10:
    print("While");
    i += 1;
# Out:
# While
# While
# While
# While
# While
# While
# While
# While
# While
# While
