# %%
age = 24;
print(age);
# Out:
# 24

# %%
name = "Fahim";
age = 24;
cgpa = 3.5;
is_food = True;

print(type(name), type(age), type(cgpa),type(is_food));
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>
